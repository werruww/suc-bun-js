# %% [markdown]
# https://huggingface.co/Xenova

# %%
# !npm install @lmstudio/sdk --save
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# added 12 packages in 6s
# ⠏
# ⠏3 packages are looking for funding
# ⠏  run `npm fund` for details
# ⠏

# %%
# %%writefile 1.js
# import { LMStudioClient } from "@lmstudio/sdk";
# const client = new LMStudioClient();
#
# const model = await client.llm.model("llama-3.2-1b-instruct");
# const result = await model.respond("What is the meaning of life?");
#
# console.info(result.content);
# Out:
# Writing 1.js

# %%
# !node 1.js
# Out:
# (node:785) [MODULE_TYPELESS_PACKAGE_JSON] Warning: Module type of file:///content/1.js is not specified and it doesn't parse as CommonJS.
# Reparsing as ES module because module syntax was detected. This incurs a performance overhead.
# To eliminate this warning, add "type": "module" to /content/package.json.
# (Use `node --trace-warnings ...` to show where the warning was created)
# node:internal/process/promises:391
#     triggerUncaughtException(err, true /* fromPromise */);
#     ^
#
# [Error:
#
# ┌ Error ──────────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │   Failed to connect to LM Studio.                                           │
# │                                                                             │
# │   Please make sure LM Studio is running on your machine.                    │
# │                                                                             │
# ...

# %%
# !bun
# Out:
# /bin/bash: line 1: bun: command not found

# %%
# %%writefile 1.js
# console.log("مرحباً بالعالم!");
# Out:
# Overwriting 1.js

# %%
# !curl -fsSL https://bun.sh/install | bash
# Out:
# ######################################################################## 100.0%
# bun was installed successfully to ~/.bun/bin/bun
#
# Added "~/.bun/bin" to $PATH in "~/.bashrc"
#
# To get started, run:
#
#   source /root/.bashrc
#   bun --help

# %%
# !source /root/.bashrc

# %%
import os
os.environ['PATH'] += ':/root/.bun/bin'

# %%
# !bun --help
# Out:
# Bun is a fast JavaScript runtime, package manager, bundler, and test runner. (1.2.11+cb6abd211)
#
# Usage: bun <command> [...flags] [...args]
#
# Commands:
#   run       ./my-script.ts       Execute a file with Bun
#             lint                 Run a package.json script
#   test                           Run unit tests with Bun
#   x         nuxi                 Execute a package binary (CLI), installing if needed (bunx)
#   repl                           Start a REPL session with Bun
#   exec                           Run a shell script directly with Bun
#
#   install                        Install dependencies for a package.json (bun i)
#   add       elysia               Add a dependency to package.json (bun a)
#   remove    webpack              Remove a dependency from package.json (bun rm)
#   update    @shumai/shumai       Update outdated dependencies
#   outdated                       Display latest versions of outdated dependencies
# ...

# %%
# !bun 1.js
# Out:
# /bin/bash: line 1: bun: command not found

# %%
# !echo "console.log('مرحباً')" | bun run -
# Out:
# مرحباً

# %%
# !source /root/.bashrc

# %%
# !bun --help
# Out:
# /bin/bash: line 1: bun: command not found

# %%
!~/.bun/bin/bun 1.js
# Out:
# مرحباً بالعالم!

# %%
# !bun --help
# Out:
# Bun is a fast JavaScript runtime, package manager, bundler, and test runner. (1.2.11+cb6abd211)
#
# Usage: bun <command> [...flags] [...args]
#
# Commands:
#   run       ./my-script.ts       Execute a file with Bun
#             lint                 Run a package.json script
#   test                           Run unit tests with Bun
#   x         nuxi                 Execute a package binary (CLI), installing if needed (bunx)
#   repl                           Start a REPL session with Bun
#   exec                           Run a shell script directly with Bun
#
#   install                        Install dependencies for a package.json (bun i)
#   add       react                Add a dependency to package.json (bun a)
#   remove    backbone             Remove a dependency from package.json (bun rm)
#   update    lyra                 Update outdated dependencies
#   outdated                       Display latest versions of outdated dependencies
# ...

# %%
# !node 1.js
# Out:
# مرحباً بالعالم!

# %%
# %%writefile your_file.js
# console.time('Execution Time');
#
# // Your code here
# for (let i = 0; i < 1000000000; i++) {
#   // Do something computationally intensive
# }
#
# console.timeEnd('Execution Time');
# Out:
# Writing your_file.js

# %%
# !node your_file.js
# Out:
# Execution Time: 1.268s

# %%
# !bun your_file.js
# Out:
# [516.56ms] Execution Time

# %% [markdown]
# هذا يعني أن Bun أسرع بحوالي 2.45 مرة من Node.js في هذا الاختبار المعين.

# %%
# %%writefile Phi-3-mini-4k-instruct.js
# import { pipeline, TextStreamer } from "@huggingface/transformers";
#
# // Create a text generation pipeline
# const generator = await pipeline(
#   "text-generation",
#   "Xenova/Phi-3-mini-4k-instruct",
# );
#
# // Define the list of messages
# const messages = [
#   { role: "user", content:  "Solve the equation: x^2 - 3x + 2 = 0" },
# ];
#
# // Create text streamer
# const streamer = new TextStreamer(generator.tokenizer, {
#   skip_prompt: true,
#   // callback_function: (text) => { }, // Optional callback function
# })
#
# // Generate a response
# const output = await generator(messages, { max_new_tokens: 512, do_sample: false, streamer });
# console.log(output[0].generated_text.at(-1).content);
# Out:
# Writing Phi-3-mini-4k-instruct.js

# %%
# !npm install @xenova/transformers

# %%
# !npm i @huggingface/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏
# up to date, audited 74 packages in 1s
# ⠏
# ⠏17 packages are looking for funding
# ⠏  run `npm fund` for details
# ⠏
# found 0 vulnerabilities
# ⠏

# %%
# !bun Phi-3-mini-4k-instruct.js
# Out:
# To solve the quadratic equation x^2 - 3x + 2 = 0, we can use the factoring method.
#
# We need to find two numbers that multiply to 2 (the constant term) and add up to -3 (the coefficient of the linear term).
#
# Those two numbers are -2 and -1, since (-2) * (-1) = 2 and (-2) + (-1) = -3.
#
# So, we can rewrite the equation as:
#
# x^2 - 2x - x + 2 = 0
#
# Now, we can factor by grouping:
#
# (x^2 - 2x) - (x - 2) = 0
#
# x(x - 2) - 1(x - 2) = 0
#
# Now, we can factor out (x - 2):
#
# (x - 2)(x - 1) = 0
#
# Now, we can set each factor equal to zero and solve for x:
#
# x - 2 = 0 or x - 1 = 0
#
# x = 2 or x = 1
#
# So, the solutions to the equation x^2 - 3x + 2 = 0 are x = 1 and x = 2.
#  To solve the quadratic equation x^2 - 3x + 2 = 0, we can use the factoring method.
#
# We need to find two numbers that multiply to 2 (the constant term) and add up to -3 (the coefficient of the linear term).
#
# Those two numbers are -2 and -1, since (-2) * (-1) = 2 and (-2) + (-1) = -3.
#
# ...

# %%
# %%writefile propositionizer-flan-t5.js
# import { pipeline, TextStreamer } from "@huggingface/transformers";
#
# // 1. Change the pipeline task and model identifier
# const generator = await pipeline(
#   "text2text-generation", // <--- Changed task for T5 models
#   "Xenova/propositionizer-wiki-flan-t5-large", // <--- Changed model name
# );
#
# // 2. Adjust the input format (simple string for text2text)
# //    Replace the complex equation with text suitable for the propositionizer
# const inputText = "The Eiffel Tower, located in Paris, France, was completed in 1889 and is a famous landmark.";
#
# // Create text streamer (optional, but works)
# // Note: Streamer might behave slightly differently depending on the model/task
# const streamer = new TextStreamer(generator.tokenizer, {
#   skip_prompt: true,
#   // callback_function: (text) => { console.log("Stream:", text); }, // Optional callback
# });
#
# console.log("Input Text:", inputText);
# console.log("Generating output...");
#
# // 3. Generate a response using the adjusted input and streamer
# const output = await generator(inputText, { // <--- Pass the string directly
#   max_new_tokens: 100, // Adjust as needed for the propositionizer task
#   do_sample: false,
#   streamer // Pass the streamer object
# });
#
# // 4. Adjust output handling
# // The output is typically an array of objects, each with generated
# Out:
# Writing propositionizer-flan-t5.js

# %% [markdown]
# الخلاصة لتشغيل Xenova/propositionizer-wiki-flan-t5-large:
# الكود الذي كتبناه لتعديل النموذج هو الصحيح وهو سيستخدم تلقائيًا ملفات ONNX الموجودة داخل مجلد onnx/ على Hugging Face Hub. لست بحاجة إلى تحديد مسارات الملفات الفردية يدويًا. المكتبة مصممة للتعامل مع هذا الأمر بسلاسة.

# %%
# !bun propositionizer-flan-t5.js
# Out:
# dtype not specified for "encoder_model". Using the default dtype (fp32) for this device (cpu).
# dtype not specified for "decoder_model_merged". Using the default dtype (fp32) for this device (cpu).
# Input Text: The Eiffel Tower, located in Paris, France, was completed in 1889 and is a famous landmark.
# Generating output...
# The Eiffel Tower is located in Paris, France.", "The Eiffel Tower was completed in 1889.", "The Eiffel Tower is a famous landmark."]

# %%
# %%writefile propositionizer-flan-t52.js
# import { pipeline, TextStreamer } from "@huggingface/transformers";
#
# // 1. Change the pipeline task and model identifier
# const generator = await pipeline(
#   "text2text-generation", // <--- Changed task for T5 models
#   "Xenova/propositionizer-wiki-flan-t5-large", // <--- Changed model name
# );
#
# // 2. Adjust the input format (simple string for text2text)
# //    Replace the complex equation with text suitable for the propositionizer
# const inputText = "Who is Napoleon Bonaparte?";
#
# // Create text streamer (optional, but works)
# // Note: Streamer might behave slightly differently depending on the model/task
# const streamer = new TextStreamer(generator.tokenizer, {
#   skip_prompt: true,
#   // callback_function: (text) => { console.log("Stream:", text); }, // Optional callback
# });
#
# console.log("Input Text:", inputText);
# console.log("Generating output...");
#
# // 3. Generate a response using the adjusted input and streamer
# const output = await generator(inputText, { // <--- Pass the string directly
#   max_new_tokens: 512, // Adjust as needed for the propositionizer task
#   do_sample: false,
#   streamer // Pass the streamer object
# });
#
# // 4. Adjust output handling
# // The output is typically an array of objects, each with generated
# Out:
# Overwriting propositionizer-flan-t52.js

# %%
# !bun propositionizer-flan-t52.js
# Out:
# dtype not specified for "encoder_model". Using the default dtype (fp32) for this device (cpu).
# dtype not specified for "decoder_model_merged". Using the default dtype (fp32) for this device (cpu).
# Input Text: Who is Napoleon Bonaparte?
# Generating output...
# king of sweden

# %%
# !bun propositionizer-flan-t52.js
# Out:
# /bin/bash: line 1: bun: command not found

# %%
# %%writefile propositionizer-flan-t5.js
# import { pipeline, TextStreamer } from "@huggingface/transformers";
#
# // 1. Change the pipeline task and model identifier
# const generator = await pipeline(
#   "text2text-generation", // <--- Changed task for T5 models
#   "Xenova/propositionizer-wiki-flan-t5-large", // <--- Changed model name
# );
#
# // 2. Adjust the input format (simple string for text2text)
# //    Replace the complex equation with text suitable for the propositionizer
# const inputText = "The Eiffel Tower, located in Paris, France, was completed in 1889 and is a famous landmark.";
#
# // Create text streamer (optional, but works)
# // Note: Streamer might behave slightly differently depending on the model/task
# const streamer = new TextStreamer(generator.tokenizer, {
#   skip_prompt: true,
#   // callback_function: (text) => { console.log("Stream:", text); }, // Optional callback
# });
#
# console.log("Input Text:", inputText);
# console.log("Generating output...");
#
# // 3. Generate a response using the adjusted input and streamer
# const output = await generator(inputText, { // <--- Pass the string directly
#   max_new_tokens: 100, // Adjust as needed for the propositionizer task
#   do_sample: false,
#   streamer // Pass the streamer object
# });
#
# // 4. Adjust output handling
# // The output is typically an array of objects, each with generated

# %% [markdown]
# https://moon-ci-docs.huggingface.co/docs/transformers.js/pr_1212/en/api/pipelines#pipelinestext2textgenerationpipeline

# %%
const generator = await pipeline('text2text-generation', 'Xenova/LaMini-Flan-T5-783M');
const output = await generator('how can I become more healthy?', {
  max_new_tokens: 100,
});
// [{ generated_text: "To become more healthy, you can: 1. Eat a balanced diet with plenty of fruits, vegetables, whole grains, lean proteins, and healthy fats. 2. Stay hydrated by drinking plenty of water. 3. Get enough sleep and manage stress levels. 4. Avoid smoking and excessive alcohol consumption. 5. Regularly exercise and maintain a healthy weight. 6. Practice good hygiene and sanitation. 7. Seek medical attention if you experience any health issues." }]

# %%
# %%writefile LaMini-Flan-T5-783M.js
#
#
#
# import { pipeline } from '@xenova/transformers';
#
# // تعريف دالة غير متزامنة لتشغيل النموذج
# async function run() {
#   // تحميل النموذج الخاص بتحويل النص إلى نص
#   const generator = await pipeline('text2text-generation', 'Xenova/LaMini-Flan-T5-783M');
#
#   // إدخال المستخدم
#   const inputText = 'how can I become more healthy?';
#
#   // تشغيل النموذج لتوليد النص
#   const output = await generator(inputText, {
#     max_new_tokens: 100,
#   });
#
#   // طباعة الناتج
#   console.log(output[0].generated_text);
# }
#
# // تشغيل الدالة
# run();
# Out:
# Writing LaMini-Flan-T5-783M.js

# %%
# !npm install @xenova/transformers
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# added 57 packages, and audited 131 packages in 12s
# ⠼
# ⠼27 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# found 0 vulnerabilities
# ⠼

# %%
# !bun LaMini-Flan-T5-783M.js
# Out:
# 2025-05-01 03:13:21.672739534 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/decoder/block.23/layer.1/layer_norm/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-05-01 03:13:21.672887043 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/decoder/block.23/layer.0/layer_norm/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-05-01 03:13:21.672903136 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/decoder/block.22/layer.2/layer_norm/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# 2025-05-01 03:13:21.672916634 [W:onnxruntime:, graph.cc:3490 CleanUnusedInitializersAndNodeArgs] Removing initializer '/decoder/block.22/layer.1/layer_norm/Constant_2_output_0'. It is not used by any node and should be removed from the model.
# ...
